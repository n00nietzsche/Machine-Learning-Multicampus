# %% [markdown]
# 필수 라이브러리 호출

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
cancer = pd.read_csv('data/wdbc.data', header = None)

# %%
type(cancer)
# Out:
# pandas.core.frame.DataFrame

# %%
cancer
# Out:
#            0  1       2      3       4       5        6        7         8   \
# 0      842302  M  17.990  10.38  122.80  1001.0  0.11840  0.27760  0.300100
# 1      842517  M  20.570  17.77  132.90  1326.0  0.08474  0.07864  0.086900
# 2    84300903  M  19.690  21.25  130.00  1203.0  0.10960  0.15990  0.197400
# 3    84348301  M  11.420  20.38   77.58   386.1  0.14250  0.28390  0.241400
# 4    84358402  M  20.290  14.34  135.10  1297.0  0.10030  0.13280  0.198000
# 5      843786  M  12.450  15.70   82.57   477.1  0.12780  0.17000  0.157800
# 6      844359  M  18.250  19.98  119.60  1040.0  0.09463  0.10900  0.112700
# 7    84458202  M  13.710  20.83   90.20   577.9  0.11890  0.16450  0.093660
# 8      844981  M  13.000  21.82   87.50   519.8  0.12730  0.19320  0.185900
# 9    84501001  M  12.460  24.04   83.97   475.9  0.11860  0.23960  0.227300
# 10     845636  M  16.020  23.24  102.70   797.8  0.08206  0.06669  0.032990
# ...

# %%
print(cancer)
# Out:
#            0  1       2      3       4       5        6        7         8   \
# 0      842302  M  17.990  10.38  122.80  1001.0  0.11840  0.27760  0.300100
# 1      842517  M  20.570  17.77  132.90  1326.0  0.08474  0.07864  0.086900
# 2    84300903  M  19.690  21.25  130.00  1203.0  0.10960  0.15990  0.197400
# 3    84348301  M  11.420  20.38   77.58   386.1  0.14250  0.28390  0.241400
# 4    84358402  M  20.290  14.34  135.10  1297.0  0.10030  0.13280  0.198000
# 5      843786  M  12.450  15.70   82.57   477.1  0.12780  0.17000  0.157800
# 6      844359  M  18.250  19.98  119.60  1040.0  0.09463  0.10900  0.112700
# 7    84458202  M  13.710  20.83   90.20   577.9  0.11890  0.16450  0.093660
# 8      844981  M  13.000  21.82   87.50   519.8  0.12730  0.19320  0.185900
# 9    84501001  M  12.460  24.04   83.97   475.9  0.11860  0.23960  0.227300
# 10     845636  M  16.020  23.24  102.70   797.8  0.08206  0.06669  0.032990
# ...

# %% [markdown]
# 일반적인 객체출력이 훨씬 보기 좋다

# %%
cancer[:5]
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9    ...        22     23      24      25      26      27      28  \
# 0  0.14710   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %% [markdown]
# 컬럼1: 환자ID, 컬럼2: 종양인가아닌가

# %%
y = target = cancer[1]

# %%
np.unique(y)
# Out:
# array(['B', 'M'], dtype=object)

# %% [markdown]
# M : 악성, B : 양성(해롭지 않은 종양)

# %%
y.value_counts()
# Out:
# B    357
# M    212
# Name: 1, dtype: int64

# %% [markdown]
# 시리즈(팬더스의 기능), np에서는 bincount를 이용하여 같은 결과를 도출할 수도 있다. (np를 이용하려면 숫자로 전부 바꿔주어야 함)

# %% [markdown]
# y값을 제외한 나머지 열들은 전부 x

# %%
X = cancer.values[:,  2:].astype('float32')

# %%
pd.DataFrame(X)[:5]
# Out:
#           0          1           2            3        4        5       6   \
# 0  17.990000  10.380000  122.800003  1001.000000  0.11840  0.27760  0.3001
# 1  20.570000  17.770000  132.899994  1326.000000  0.08474  0.07864  0.0869
# 2  19.690001  21.250000  130.000000  1203.000000  0.10960  0.15990  0.1974
# 3  11.420000  20.379999   77.580002   386.100006  0.14250  0.28390  0.2414
# 4  20.290001  14.340000  135.100006  1297.000000  0.10030  0.13280  0.1980
#
#         7       8        9    ...            20         21          22  \
# 0  0.14710  0.2419  0.07871   ...     25.379999  17.330000  184.600006
# 1  0.07017  0.1812  0.05667   ...     24.990000  23.410000  158.800003
# 2  0.12790  0.2069  0.05999   ...     23.570000  25.530001  152.500000
# 3  0.10520  0.2597  0.09744   ...     14.910000  26.500000   98.870003
# 4  0.10430  0.1809  0.05883   ...     22.540001  16.670000  152.199997
#
#             23      24      25      26      27      28       29
# ...

# %%
x.shape
# Out:
# (569, 30)

# %% [markdown]
# 데이터 포인트 = 샘플

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %% [markdown]
# 생성자로 객체를 생성해야 하는데 객체 그 자체를 대입해서 에러

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %% [markdown]
# ```
# minkowski -> 거리 측정 방식
# n_neighbors = 5 -> 주변에 몇 개의 데이터를 참조?
# ```

# %%
y_pred = model.predict(X_test)

# %%
y_pred[:5]
# Out:
# array(['B', 'B', 'B', 'M', 'B'], dtype=object)

# %%
np.mean(y_pred == y_test)
# Out:
# 0.93706293706293708

# %%
model.score(X_test, y_test)
# Out:
# 0.93706293706293708

# %%
model.score(X_train, y_train)
# Out:
# 0.9460093896713615

# %% [markdown]
# ```
# 훈련데이터에 대해서 100점을 못 맞는 이유?
#  -> 군집화 시에 어긋나는 데이터의 존재 유무, 이웃 수가 많아질수록 어긋나는 데이터가 나올 확률이 높다
# ```

# %% [markdown]
# 이웃수 설정에 따른 모델 성능 평가

# %%
훈련결과 = []
for 이웃수 in range(1, 11):
    model = KNeighborsClassifier(n_neighbors=이웃수)
    model.fit(X_train, y_train)
    훈련점수 = model.score(X_train, y_train)
    시험점수 = model.score(X_test, y_test)
    훈련결과.append((훈련점수, 시험점수))

# %%
훈련평가 = pd.DataFrame(훈련결과, columns=['train', 'test'])

# %%
훈련평가
# Out:
#       train      test
# 0  1.000000  0.916084
# 1  0.946009  0.944056
# 2  0.955399  0.937063
# 3  0.946009  0.937063
# 4  0.946009  0.937063
# 5  0.943662  0.937063
# 6  0.938967  0.937063
# 7  0.931925  0.930070
# 8  0.938967  0.923077
# 9  0.936620  0.923077

# %%
훈련평가.plot(style={'train' : 'g', 'test' : 'r'})

# %% [markdown]
# ```
# 참조하는 이웃(N) = 1인 경우에는 과대적합이 발생하여, 일반화 성능이 낮아진다.
#  -> 일반화 성능이 낮아지는 것은 새로운 데이터에 대한 적응력이 낮음을 의미
#
# 하지만 무조건 일반화 성능이 가장 좋은 N을 선택해야 되는가에 대해서는 합당한 이유가 필요하다.
# ```

# %% [markdown]
# # 회귀

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
X = boston.data
y = boston.target
열제목 = boston.feature_names

# %%
pd.DataFrame(X, columns=열제목)[:5]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
X.shape
# Out:
# (506, 13)

# %%
y[:5]
# Out:
# array([ 24. ,  21.6,  34.7,  33.4,  36.2])

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor()
model
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
y_pred = model.predict(X_test)

# %%
y_pred[:5]
# Out:
# array([ 23.48,  17.48,  23.72,  13.  ,  38.44])

# %%
y_pred == y_test
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.52288185822269939

# %%
model.score(X_test, y_test)
# Out:
# 0.52288185822269939

# %% [markdown]
# ```
# Q. 과소적합이 발생했을 때의 해결책은?
#  -> test 결과 점수가 너무 낮다면 훈련 점수를 올려보기 (이웃의 갯수를 줄여보자)
# ```

# %%
knn_1 = KNeighborsRegressor(n_neighbors=1)
knn_1.fit(X_train, y_train)
훈련점수 = knn_1.score(X_train, y_train)
시험점수 = knn_1.score(X_test, y_test)

훈련점수, 시험점수
# Out:
# (1.0, 0.49241514345326742)

# %%
훈련결과 = []
for 이웃수 in range(2, 6):
    model = KNeighborsRegressor(n_neighbors=이웃수)
    model.fit(X_train, y_train)
    훈련점수 = model.score(X_train, y_train)
    시험점수 = model.score(X_test, y_test)
    훈련결과.append((훈련점수, 시험점수))
    
훈련평가 = pd.DataFrame(훈련결과, columns=['train', 'test'])
훈련평가.index = range(2, 6)
훈련평가
# Out:
#       train      test
# 2  0.832106  0.529994
# 3  0.756734  0.531671
# 4  0.704174  0.556054
# 5  0.667843  0.522882

# %%
훈련평가.plot(style={'train' : 'go--', 'test' : 'ro--'}, ylim=(0.0, 1.0))

# %% [markdown]
# 모델 튜닝의 필요

# %% [markdown]
# # 선형모델

# %%
x = np.arange(1, 100)

# %%
plt.plot(x)

# %%
x = np.linspace(0, 10, 100)

# %%
y = x + np.random.randn(len(x)) * 0.9

# %%
plt.scatter(x, y)

# %%
X = x.reshape(100, 1)

# %%
X[:5]
# Out:
# array([[ 0.       ],
#        [ 0.1010101],
#        [ 0.2020202],
#        [ 0.3030303],
#        [ 0.4040404]])

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False)

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred_train = linreg.predict(X_train)
y_pred_test = linreg.predict(X_test)

# %% [markdown]
# # 선형회귀 Lin. Reg.

# %%
x_tr = X_train.flatten()
x_te = X_test.flatten()

plt.scatter(x, y)
plt.scatter(x_tr, y_pred_train, color='g')
plt.scatter(x_te, y_pred_test, color='r')

# %%
w = linreg.coef_
b = linreg.intercept_

w, b
# Out:
# (array([ 1.00883726]), -0.0017951728771889996)

# %%
boston = pd.read_csv('data/boston.csv')
boston[:5]
# Out:
#    Price     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = boston['Price']
X = boston.values[:, 1:].astype('float32')

# %%
X.shape
# Out:
# (506, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
linreg = LinearRegression().fit(X_train, y_train)

# %%
linreg.score(X_test, y_test)
# Out:
# 0.66641711693750061

# %% [markdown]
# 항상 훈련, 테스트 둘 다 확인하여 과적합을 확인하여야 한다.

# %%
linreg.score(X_train, y_train)
# Out:
# 0.76503493716586712

# %%
w = linreg.coef_
b = linreg.intercept_

# %%
w.shape
# Out:
# (13,)

# %%
b
# Out:
# 27.655079

# %% [markdown]
# Q: 특징과 가중치의 관계 해석?

# %%
pd.Series(w, index=boston.columns[1:])
# Out:
# CRIM       -0.114300
# ZN          0.048372
# INDUS       0.027835
# CHAS        3.151377
# NOX       -15.431976
# RM          4.293736
# AGE         0.001481
# DIS        -1.330936
# RAD         0.295505
# TAX        -0.011162
# PTRATIO    -0.881198
# B           0.013632
# LSTAT      -0.478379
# dtype: float32

# %% [markdown]
# ```
# 각각 요소들이 가지는 가중치에 따라 그 지표가 얼마나 중요한지 알 수 있음
# ex) CRIM -> 범죄율은 그렇게 크게 영향을 미치지 않는다.
# ```

# %% [markdown]
# ```
# 결과가 잘 안나올 때..
#  1 -> 모델 변경
#  2 -> 데이터 변경
# ```

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
다항식 = PolynomialFeatures(degree=2)

# %% [markdown]
# fit에 y를 주어주지 않으면 비지도학습과 관련

# %%
다항식.fit(X_train)
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)

# %%
XX_train = 다항식.transform(X_train)
XX_test = 다항식.transform(X_test)

# %% [markdown]
# 특성의 갯수를 늘려보기

# %%
X_train.shape, XX_train.shape
# Out:
# ((379, 13), (379, 105))

# %%
linreg.fit(XX_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.score(XX_test, y_test)
# Out:
# 0.77520555012721404

# %%
linreg.score(XX_train, y_train)
# Out:
# 0.91610930544948921

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge(alpha=1.0).fit(XX_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.1234770891377366e-09
#   ' condition number: {}'.format(rcond), RuntimeWarning)

# %%
ridge.score(XX_test, y_test)
# Out:
# 0.83598850853051043

# %%
훈련결과 = []
alpha_range = [0.001, 0.01, 0.1, 1., 10., 100., 1000]
가중치목록 = []
for alpha in alpha_range:
    model = Ridge(alpha=alpha)
    model.fit(XX_train, y_train)
    가중치목록.append(model.coef_) #가중치를 수집
    훈련점수 = model.score(XX_train, y_train)
    시험점수 = model.score(XX_test, y_test)
    훈련결과.append((훈련점수, 시험점수))
    
훈련평가 = pd.DataFrame(훈련결과, columns=['train', 'test'])
훈련평가.index = alpha_range
훈련평가
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.060629468926606e-10
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.268312228805087e-10
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.531326838896348e-10
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# ...

# %% [markdown]
# logx=True 옵션은 그래프를 로그스케일로

# %%
훈련평가.plot(logx=True, style=train_test_styles)

# %%
train_test_styles = {'train' : 'go--', 'test' : 'ro--'}

# %%
가중치배열 = np.array(가중치목록)

# %%
가중치배열.shape
# Out:
# (7, 105)

# %%
가중치크기 = np.sum(가중치배열**2, axis=1)

# %%
가중치크기
# Out:
# array([  5.03763086e+03,   1.02350464e+03,   3.17830536e+02,
#          7.83595657e+01,   1.72522144e+01,   1.67880011e+00,
#          1.64556578e-01], dtype=float32)

# %%
plt.plot(가중치크기)

# %%
X.shape
# Out:
# (506, 13)

# %% [markdown]
# 적절한 샘플 수는?
